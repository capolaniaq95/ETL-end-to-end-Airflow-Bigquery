# %%
import requests

url_1 = f"https://api.frankfurter.app/2022-03-01?from=EUR&to=USD"

url_2 = "https://api.frankfurter.dev/v1/latest?symbols=USD"

response_1 = requests.get(url_1)
data_1 = response_1.json()

response_2 = requests.get(url_2)
data_2 = response_2.json()

# %%
data_1
# Out:
# {'amount': 1.0, 'base': 'EUR', 'date': '2022-03-01', 'rates': {'USD': 1.1162}}

# %%
data_2
# Out:
# {'amount': 1.0, 'base': 'EUR', 'date': '2026-01-05', 'rates': {'USD': 1.1664}}
